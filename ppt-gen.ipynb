# %% [markdown]
# # Generate a PowerPoint With an LLM
#
# This is the notebook related to the Medium article *[How to Generate a PowerPoint With an LLM](https://medium.com/@matteo28/how-to-generate-a-powerpoint-with-an-llm-3b0448a48125)*.
#
# In this notebook there is code to be able to create a powerpoint using the OpenAI API to take advantage of the GPT4o-mini templates for text generation and DALLE-3 for image generation.

# %%
# !pip install -r requirements.txt

# %%
import openai
import requests
import json
import os
import re
from llama_index.core import PromptTemplate
from llama_index.llms.openai import OpenAI
from pptx import Presentation
from config import Config

# %% [markdown]
# ## Load template

# %%
template_path = os.path.join(Config.TEMPLATES_PATH, 'basic_template.pptx')
prs = Presentation(template_path)

# %%
slide_structures = []

# Iterate through each slide in the presentation
for slide in prs.slides:
    structure = {"placeholders": []}
    
    # Iterate through each shape in the slide
    for shape in slide.shapes:
        if shape.is_placeholder:
            
            # Create a dictionary to store placeholder details
            placeholder = {
                "type": shape.placeholder_format.type,
                "idx": shape.placeholder_format.idx,
                "has_text_frame": shape.has_text_frame,
                "name": shape.name,
            }
            # Check if the placeholder contains a table
            if shape.has_table:
                placeholder["has_table"] = True
                # Extract the table structure as a list of rows with cell texts
                placeholder["table_structure"] = [
                    [cell.text for cell in row.cells] for row in shape.table.rows
                ]
            else:
                placeholder["has_table"] = False
            
            # Check if the placeholder is an image placeholder
            if shape.placeholder_format.type == 18:
                placeholder["has_image"] = True
                placeholder["image_description"] = ""
            else:
                placeholder["has_image"] = False

            # Append the placeholder information to the structure
            structure["placeholders"].append(placeholder)
            
    # Append the slide structure to the list of all slide structures
    slide_structures.append(structure)

# Convert the structure list to a JSON string for better readability
slide_structures_str = json.dumps(slide_structures, indent=4)

# %%
import pprint
pprint.pprint(slide_structures_str)
# Out:
# ('[\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 15,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 14,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 17",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 6",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 8",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 6",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 4,\n'
#  '                "idx": 1,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Subtitle 7",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 8",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 6",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Subtitle 7",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 12,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 11",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 12",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 1,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 3",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 14,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 9",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 17",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 12,\n'
#  '                "idx": 11,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Content Placeholder 18",\n'
#  '                "has_table": true,\n'
#  '                "table_structure": [\n'
#  '                    [\n'
#  '                        "Metric",\n'
#  '                        "Measurement",\n'
#  '                        "Target",\n'
#  '                        "Actual"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Audience attendance",\n'
#  '                        "# of attendees",\n'
#  '                        "150",\n'
#  '                        "120"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Engagement duration",\n'
#  '                        "Minutes",\n'
#  '                        "60",\n'
#  '                        "75"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Q&A interaction",\n'
#  '                        "# of questions",\n'
#  '                        "10",\n'
#  '                        "15"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Positive feedback",\n'
#  '                        "Percentage (%)",\n'
#  '                        "90",\n'
#  '                        "95"\n'
#  '                    ]\n'
#  '                ],\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 11,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 3",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 12,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Content Placeholder 3",\n'
#  '                "has_table": true,\n'
#  '                "table_structure": [\n'
#  '                    [\n'
#  '                        "Impact factor",\n'
#  '                        "Measurement",\n'
#  '                        "Target",\n'
#  '                        "Achieved"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Audience interaction",\n'
#  '                        "Percentage (%)",\n'
#  '                        "85",\n'
#  '                        "88"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Knowledge retention",\n'
#  '                        "Percentage (%)",\n'
#  '                        "75",\n'
#  '                        "80"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Post-presentation surveys",\n'
#  '                        "Average rating",\n'
#  '                        "4.2",\n'
#  '                        "4.5"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Referral rate",\n'
#  '                        "Percentage (%)",\n'
#  '                        "10",\n'
#  '                        "12"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Collaboration opportunities",\n'
#  '                        "# of opportunities",\n'
#  '                        "8",\n'
#  '                        "10"\n'
#  '                    ]\n'
#  '                ],\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 15,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    }\n'
#  ']')

# %% [markdown]
# ## Prompting

# %%
prompt = """
You are a PowerPoint presentation specialist. You are asked to create content for a presentation about {topic}.
The PowerPoint template has the following structure:

{structure}

You need to generate content that fits into this structure, ensuring that all placeholders are filled appropriately.

For each slide:
1. Provide the title for the slide.
2. Provide the text content for each text placeholder.
3. If a slide contains a table, generate appropriate data to fill it based on the provided context.
4. If a slide contains an image placeholder, describe the type of image that should be included.

Return the structured information *only* as a JSON. Do not include any introductory text or explanations.
"""

prompt_template = PromptTemplate(template=prompt)

test_topic = "Create an example of pitch for a new product named \"Nose\", a platform that helps investors to find the best investment opportunities."

content_prompt = (
    prompt_template.format(topic=test_topic, structure=slide_structures_str)
)

# %% [markdown]
# ## LLM

# %%
llm = OpenAI(model="gpt-4o-mini", api_key=os.environ["OPENAI_API_KEY"])
slides_response = llm.complete(content_prompt, True).text

# %%
print(slides_response)
# Out:
# ```json
# [
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 1",
#                 "text": "Introducing Nose: Your Investment Companion"
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 1",
#                 "text": "What is Nose?"
#             },
#             {
#                 "type": 7,
#                 "idx": 15,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 2",
#                 "text": "Nose is a cutting-edge platform designed to help investors discover the best investment opportunities tailored to their preferences and risk profiles. With advanced algorithms and real-time data analysis, Nose simplifies the investment process."
#             },
#             {
#                 "type": 18,
#                 "idx": 14,
#                 "has_text_frame": false,
#                 "name": "Picture Placeholder 17",
#                 "image_description": "An infographic showing the features of the Nose platform, including data analysis, user-friendly interface, and personalized recommendations."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 6",
#                 "text": "Key Features of Nose"
#             },
#             {
#                 "type": 18,
#                 "idx": 13,
#                 "has_text_frame": false,
#                 "name": "Picture Placeholder 8",
#                 "image_description": "A screenshot of the Nose platform interface showcasing its dashboard and analytics."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 6",
#                 "text": "How Does Nose Work?"
#             },
#             {
#                 "type": 4,
#                 "idx": 1,
#                 "has_text_frame": true,
#                 "name": "Subtitle 7",
#                 "text": "Step-by-Step Process"
#             },
#             {
#                 "type": 18,
#                 "idx": 13,
#                 "has_text_frame": false,
#                 "name": "Picture Placeholder 8",
#                 "image_description": "A flowchart illustrating the process of using Nose, from user registration to investment selection."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 2",
#                 "text": "Market Opportunity"
#             },
#             {
#                 "type": 7,
#                 "idx": 10,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 1",
#                 "text": "The investment landscape is rapidly evolving, with more individuals seeking guidance in navigating opportunities. Nose addresses this need by providing a comprehensive platform that connects investors with high-potential ventures."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 6",
#                 "text": "Target Audience"
#             },
#             {
#                 "type": 7,
#                 "idx": 10,
#                 "has_text_frame": true,
#                 "name": "Subtitle 7",
#                 "text": "Who Can Benefit from Nose?"
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 1",
#                 "text": "Nose's Unique Value Proposition"
#             },
#             {
#                 "type": 7,
#                 "idx": 12,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 11",
#                 "text": "Nose combines technology with personalized investment strategies, ensuring users receive tailored recommendations that align with their financial goals."
#             },
#             {
#                 "type": 7,
#                 "idx": 13,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 12",
#                 "text": "Our platform not only identifies opportunities but also provides insights and analytics to help investors make informed decisions."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 1",
#                 "text": "Success Metrics"
#             },
#             {
#                 "type": 7,
#                 "idx": 1,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 2",
#                 "text": "We measure our success through user engagement, satisfaction, and investment outcomes."
#             },
#             {
#                 "type": 7,
#                 "idx": 13,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 3",
#                 "text": "Our goal is to achieve a 90% user satisfaction rate and a significant increase in successful investments."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 1",
#                 "text": "Future Roadmap"
#             },
#             {
#                 "type": 18,
#                 "idx": 14,
#                 "has_text_frame": false,
#                 "name": "Picture Placeholder 9",
#                 "image_description": "A timeline graphic showing the future development plans for the Nose platform, including new features and expansion goals."
#             },
#             {
#                 "type": 7,
#                 "idx": 10,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 2",
#                 "text": "Nose aims to continuously evolve by integrating user feedback and expanding our investment options to cater to a broader audience."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 1",
#                 "text": "Join Us on This Journey"
#             },
#             {
#                 "type": 7,
#                 "idx": 11,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 2",
#                 "text": "Invest with confidence. Discover the best opportunities with Nose and be part of a community that values informed investing."
#             },
#             {
#                 "type": 7,
#                 "idx": 10,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 3",
#                 "text": "Together, we can redefine the investment landscape."
#             }
#         ]
#     },
#     {
#         "placeholders": [
#             {
#                 "type": 1,
#                 "idx": 0,
#                 "has_text_frame": true,
#                 "name": "Title 1",
#                 "text": "Thank You!"
#             },
#             {
#                 "type": 7,
#                 "idx": 15,
#                 "has_text_frame": true,
#                 "name": "Content Placeholder 2",
#                 "text": "For more information, visit our website or contact us directly."
#             }
#         ]
#     }
# ]
# ```

# %%
json_match = re.search(r'```json\s*(.*?)\s*```', slides_response, re.DOTALL)

if json_match:
    json_content = json_match.group(1)
    try:
        slides = json.loads(json_content)
    except json.JSONDecodeError as e:
        raise ValueError(f"JSON parsing error: {str(e)}")
else:
    raise ValueError("The JSON was not found in the model response.")

# %%
pprint.pprint(slides)
# Out:
# [{'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Introducing Nose: Your Investment Companion',
#                     'type': 1}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'What is Nose?',
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 15,
#                     'name': 'Content Placeholder 2',
#                     'text': 'Nose is a cutting-edge platform designed to help '
#                             'investors discover the best investment '
#                             'opportunities tailored to their preferences and '
#                             'risk profiles. With advanced algorithms and '
#                             'real-time data analysis, Nose simplifies the '
#                             'investment process.',
#                     'type': 7},
#                    {'has_text_frame': False,
#                     'idx': 14,
#                     'image_description': 'An infographic showing the features '
#                                          'of the Nose platform, including data '
#                                          'analysis, user-friendly interface, '
#                                          'and personalized recommendations.',
#                     'name': 'Picture Placeholder 17',
#                     'type': 18}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 6',
#                     'text': 'Key Features of Nose',
#                     'type': 1},
#                    {'has_text_frame': False,
#                     'idx': 13,
#                     'image_description': 'A screenshot of the Nose platform '
#                                          'interface showcasing its dashboard '
#                                          'and analytics.',
#                     'name': 'Picture Placeholder 8',
#                     'type': 18}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 6',
#                     'text': 'How Does Nose Work?',
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 1,
#                     'name': 'Subtitle 7',
#                     'text': 'Step-by-Step Process',
#                     'type': 4},
#                    {'has_text_frame': False,
#                     'idx': 13,
#                     'image_description': 'A flowchart illustrating the process '
#                                          'of using Nose, from user '
#                                          'registration to investment '
#                                          'selection.',
#                     'name': 'Picture Placeholder 8',
#                     'type': 18}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 2',
#                     'text': 'Market Opportunity',
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Content Placeholder 1',
#                     'text': 'The investment landscape is rapidly evolving, '
#                             'with more individuals seeking guidance in '
#                             'navigating opportunities. Nose addresses this '
#                             'need by providing a comprehensive platform that '
#                             'connects investors with high-potential ventures.',
#                     'type': 7}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 6',
#                     'text': 'Target Audience',
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Subtitle 7',
#                     'text': 'Who Can Benefit from Nose?',
#                     'type': 7}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': "Nose's Unique Value Proposition",
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 12,
#                     'name': 'Content Placeholder 11',
#                     'text': 'Nose combines technology with personalized '
#                             'investment strategies, ensuring users receive '
#                             'tailored recommendations that align with their '
#                             'financial goals.',
#                     'type': 7},
#                    {'has_text_frame': True,
#                     'idx': 13,
#                     'name': 'Content Placeholder 12',
#                     'text': 'Our platform not only identifies opportunities '
#                             'but also provides insights and analytics to help '
#                             'investors make informed decisions.',
#                     'type': 7}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Success Metrics',
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 1,
#                     'name': 'Content Placeholder 2',
#                     'text': 'We measure our success through user engagement, '
#                             'satisfaction, and investment outcomes.',
#                     'type': 7},
#                    {'has_text_frame': True,
#                     'idx': 13,
#                     'name': 'Content Placeholder 3',
#                     'text': 'Our goal is to achieve a 90% user satisfaction '
#                             'rate and a significant increase in successful '
#                             'investments.',
#                     'type': 7}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Future Roadmap',
#                     'type': 1},
#                    {'has_text_frame': False,
#                     'idx': 14,
#                     'image_description': 'A timeline graphic showing the '
#                                          'future development plans for the '
#                                          'Nose platform, including new '
#                                          'features and expansion goals.',
#                     'name': 'Picture Placeholder 9',
#                     'type': 18},
#                    {'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Content Placeholder 2',
#                     'text': 'Nose aims to continuously evolve by integrating '
#                             'user feedback and expanding our investment '
#                             'options to cater to a broader audience.',
#                     'type': 7}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Join Us on This Journey',
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 11,
#                     'name': 'Content Placeholder 2',
#                     'text': 'Invest with confidence. Discover the best '
#                             'opportunities with Nose and be part of a '
#                             'community that values informed investing.',
#                     'type': 7},
#                    {'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Content Placeholder 3',
#                     'text': 'Together, we can redefine the investment '
#                             'landscape.',
#                     'type': 7}]},
#  {'placeholders': [{'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Thank You!',
#                     'type': 1},
#                    {'has_text_frame': True,
#                     'idx': 15,
#                     'name': 'Content Placeholder 2',
#                     'text': 'For more information, visit our website or '
#                             'contact us directly.',
#                     'type': 7}]}]

# %%
def generate_image(description):
    response = openai.images.generate(
        model="dall-e-3",
        prompt=description,
        n=1,
        response_format="url",
    )
    image_url = response.data[0].url
    image_data = requests.get(image_url).content
    return image_data

# %%
def populate_slide(slide, slide_data):
    # Get the list of placeholders
    placeholders = slide_data.get("placeholders", [])

    # Popolare i placeholders di testo
    for placeholder in placeholders:
        for shape in slide.shapes:
            if shape.is_placeholder and placeholder.get("name") in shape.name:
                if placeholder.get("text") and shape.has_text_frame:
                    shape.text = placeholder["text"]

    # Populate text placeholders
    for placeholder in placeholders:
        if placeholder.get("image_description"):
            image_data = generate_image(placeholder["image_description"])
            img_path = "temp_image.png"
            with open(img_path, "wb") as img_file:
                img_file.write(image_data)
            for shape in slide.shapes:
                if shape.is_placeholder and shape.placeholder_format.type == 18:
                    slide.shapes._spTree.remove(shape._element)
                    slide.shapes.add_picture(img_path, shape.left, shape.top, shape.width, shape.height)
                    break

    # Populate the tables
    for placeholder in placeholders:
        table_data = placeholder.get("table_structure")
        if table_data:
            for shape in slide.shapes:
                if shape.has_table:
                    table = shape.table
                    for i, row_data in enumerate(table_data):
                        for j, cell_text in enumerate(row_data):
                            table.cell(i, j).text = cell_text
                    break

# %%
for i, slide_data in enumerate(slides):
    if i < len(prs.slides):
        populate_slide(prs.slides[i], slide_data)

# %%
save_path = os.path.join(Config.POWERPOINTS_PATH, "output.pptx")
prs.save(save_path)
